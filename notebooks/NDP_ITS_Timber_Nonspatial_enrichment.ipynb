# %% [markdown]
# ## **Install Required Python Libraries**
#
# You are editing this notebook, so we assume you have already cloned the repository from
# [https://github.com/klinucsd/interagency-tracking-system](https://github.com/klinucsd/interagency-tracking-system) into the folder ~/work/interagency-tracking-system. Please verify that the `requirements.txt` file is available in that folder before proceeding.

# %%
! pip install -r requirements.txt

# %% [markdown]
# ## **Unzip Reference Data in GDB format**

# %%
! unzip -o ../a_Reference.gdb.zip

# %% [markdown]
# ## **Download Timber Industry data**

# %%
from utils.download_from_box import download_box_shared_link

timber_industry_box_link = 'https://calfire.box.com/s/v6nq58rnrzho03obbi36702864kkdtjg'
download_box_shared_link(timber_industry_box_link)
# Out:
# Accessing shared link...
# Found 1 file(s)
#
# [1/1] Downloading: Timber Industry Acres 2024 for UCSD 13May2025.xlsx
#     ✓ Saved: Timber Industry Acres 2024 for UCSD 13May2025.xlsx (11,541 bytes)
# ['./Timber Industry Acres 2024 for UCSD 13May2025.xlsx']

# %% [markdown]
# ## **Enriching Timber Industry Data**
#
# Converts the Timber Industry actual treatments dataset into the Task Force standardized schema. Dataset is enriched with vegetation, ownership, county, WUI, Task Force Region, and year.

# %%
import warnings
import logging
import time
from datetime import datetime
import psutil
import os
from enrich.enrich_Timber_Nonspatial import enrich_Timber_Nonspatial

# Get the current process ID
process = psutil.Process(os.getpid())

tn_input_excel_path = "Timber Industry Acres 2024 for UCSD 13May2025.xlsx"
a_reference_gdb_path = "a_Reference.gdb"
start_year, end_year = 2021, 2025
output_gdb_path = f"/tmp/Timber_Nonspatial_{start_year}_{end_year}.gdb"
output_layer_name = f"Timber_Nonspatial_{datetime.today().strftime('%Y%m%d')}"

enrich_Timber_Nonspatial(tn_input_excel_path,
                         a_reference_gdb_path,
                         start_year,
                         end_year,
                         output_gdb_path,
                         output_layer_name)

# Get memory usage in bytes, convert to MB
memory_usage = process.memory_info().rss / 1024 / 1024
print(f"Memory usage: {memory_usage:.2f} MB")
# Out:
# 2025-12-12 18:12:06,070 INFO  [enrich.Timber_NSpatial]  Load the Timeber Industry Nonspatial data into a DataFrame
# 2025-12-12 18:12:06,080 INFO  [enrich.Timber_NSpatial]     time for loading Timber Industry Acres 2024 for UCSD 13May2025.xlsx: 0.008952617645263672
# 2025-12-12 18:12:06,080 INFO  [enrich.Timber_NSpatial]  Performing Standardization
# 2025-12-12 18:12:06,081 INFO  [enrich.Timber_NSpatial]     step 1/10 convert Excel sheet to table
# 2025-12-12 18:12:06,089 INFO  [enrich.Timber_NSpatial]     all required columns are present.
# 2025-12-12 18:12:06,089 INFO  [enrich.Timber_NSpatial]     step 2/10 rename and add fields
# 2025-12-12 18:12:06,091 INFO  [enrich.Timber_NSpatial]     step 3/10 adding common columns...
# 2025-12-12 18:12:06,145 INFO  [enrich.Timber_NSpatial]     step 4/10 calculate fields
# 2025-12-12 18:12:06,150 INFO  [enrich.Timber_NSpatial]     step 5/10 converting Table to Geodataframe
# 2025-12-12 18:12:06,200 INFO  [enrich.Timber_NSpatial]     step 6/10 Remove Unnecessary Columns...
# 2025-12-12 18:12:06,203 INFO  [enrich.Timber_NSpatial]     step 7/10 Enrich Points
# 2025-12-12 18:12:06,204 INFO  [utils.enrich_points   ]        Executing Point Enrichments...
# 2025-12-12 18:12:06,205 INFO  [utils.enrich_points   ]           Calculating WUI...
# 2025-12-12 18:12:06,206 INFO  [utils.enrich_points   ]              enrich step 1/16 loading WUI from cache
# 2025-12-12 18:12:06,484 INFO  [utils.enrich_points   ]                 time for loading WUI: 0.2778642177581787
# 2025-12-12 18:12:06,484 INFO  [utils.enrich_points   ]              enrich step 2/16 select records with null WUI
# 2025-12-12 18:12:06,487 INFO  [utils.enrich_points   ]              enrich step 3/16 select by WUI location
# 2025-12-12 18:12:06,529 INFO  [utils.enrich_points   ]              enrich step 4/16 calculate WUI yes
# 2025-12-12 18:12:06,530 INFO  [utils.enrich_points   ]              enrich step 5/16 select remaining null records
# 2025-12-12 18:12:06,533 INFO  [utils.enrich_points   ]              enrich step 6/16 calculate WUI no
# 2025-12-12 18:12:06,534 INFO  [utils.enrich_points   ]           Calculating Ownership, Counties, and Regions...
# 2025-12-12 18:12:06,534 INFO  [utils.enrich_points   ]              enrich step 7/16 loading CALFIRE_Ownership_Update from cache
# 2025-12-12 18:12:07,269 INFO  [utils.enrich_points   ]                 time for loading CALFIRE_Ownership_Update: 0.734623908996582
# 2025-12-12 18:12:07,270 INFO  [utils.enrich_points   ]              enrich step 8/16 spatial join ownership
# 2025-12-12 18:12:07,870 INFO  [utils.enrich_points   ]              enrich step 9/16 loading WFRTF_Regions from cache
# 2025-12-12 18:12:07,892 INFO  [utils.enrich_points   ]                 time for loading WFRTF_Regions: 0.0219879150390625
# 2025-12-12 18:12:07,892 INFO  [utils.enrich_points   ]              enrich step 10/16 spatial join regions
# 2025-12-12 18:12:07,937 INFO  [utils.enrich_points   ]              enrich step 11/16 loading Broad_Vegetation_Types from cache
# 2025-12-12 18:12:20,507 INFO  [utils.enrich_points   ]                 time for loading Broad_Vegetation_Types: 12.636841535568237
# 2025-12-12 18:12:20,508 INFO  [utils.enrich_points   ]              enrich step 12/16 spatial join veg and calculations
# 2025-12-12 18:12:34,838 INFO  [utils.enrich_points   ]              enrich step 13/16 Initiating Crosswalk
# 2025-12-12 18:12:34,839 INFO  [utils.crosswalk       ]           Calculating Crosswalking Activites...
# 2025-12-12 18:12:34,840 INFO  [utils.crosswalk       ]              Load Crosswalk table...
# 2025-12-12 18:12:34,853 INFO  [utils.crosswalk       ]              cross step 1/8 add join
# 2025-12-12 18:12:34,857 INFO  [utils.crosswalk       ]              cross step 2/8 calculate activities
# 2025-12-12 18:12:34,859 INFO  [utils.crosswalk       ]              cross step 3/8 calculate residue fate field
# 2025-12-12 18:12:34,861 INFO  [utils.crosswalk       ]              cross step 4/8 select attribute by layer
# 2025-12-12 18:12:34,862 INFO  [utils.crosswalk       ]              cross step 5/8 calculating objective...
# 2025-12-12 18:12:34,865 INFO  [utils.crosswalk       ]              cross step 6/8 calculate category
# 2025-12-12 18:12:34,869 INFO  [utils.crosswalk       ]              cross step 7/8 standardize domains
# 2025-12-12 18:12:34,877 INFO  [utils.crosswalk       ]              cross step 8/8 counts towards MAS
# 2025-12-12 18:12:34,878 INFO  [utils.counts_to_mas   ]           Calculating Counts to MAS
# 2025-12-12 18:12:34,879 INFO  [utils.counts_to_mas   ]              counts step 1/8: set to 'NO'
# 2025-12-12 18:12:34,880 INFO  [utils.counts_to_mas   ]              counts step 2/8: select by bounding years (2021-2025)
# 2025-12-12 18:12:34,881 INFO  [utils.counts_to_mas   ]              counts step 3/8: set to 'YES' if activity description is in the list
# 2025-12-12 18:12:34,883 INFO  [utils.counts_to_mas   ]              counts step 4/8: set to 'NO' if not 'Acres'
# 2025-12-12 18:12:34,883 INFO  [utils.counts_to_mas   ]              counts step 5/8: set to 'NO' if status is 'Canceled', 'Planned', 'Outyear', or 'Proposed'
# 2025-12-12 18:12:34,885 INFO  [utils.counts_to_mas   ]              counts step 6/8: set to 'NO' if Activity Category is 'Watershed Improvement'
# 2025-12-12 18:12:34,885 INFO  [utils.counts_to_mas   ]              counts step 7/8: set to 'NO' if Agency is 'Other' and Admin is 'CARB'
# 2025-12-12 18:12:34,887 INFO  [utils.counts_to_mas   ]              counts step 8/8: set to 'NO' if Org is 'USFS' and Status is 'Active'
# 2025-12-12 18:12:34,891 INFO  [utils.enrich_points   ]           Crosswalk Complete. Continuing Enrichment...
# 2025-12-12 18:12:34,893 INFO  [utils.enrich_points   ]              enrich step 14/16 calculating Years
# 2025-12-12 18:12:34,895 INFO  [utils.enrich_points   ]              enrich step 15/16 calculating Latitude and Longitude
# 2025-12-12 18:12:34,898 INFO  [utils.enrich_points   ]              enrich step 16/16 removing unnecessary fields
# 2025-12-12 18:12:34,900 INFO  [utils.enrich_points   ]           Enrich Points Complete...
# 2025-12-12 18:12:35,147 INFO  [enrich.Timber_NSpatial]     step 8/10 Fix board veg types and others
# 2025-12-12 18:12:35,152 INFO  [enrich.Timber_NSpatial]     step 9/10 Assign Domains...
# 2025-12-12 18:12:35,191 INFO  [utils.assign_domains  ]        Created domain 'D_OBJECTIVE' with 27 values
# 2025-12-12 18:12:35,195 INFO  [utils.assign_domains  ]        Created domain 'D_STATUS' with 6 values
# 2025-12-12 18:12:35,202 INFO  [utils.assign_domains  ]        Created domain 'D_CNTY' with 59 values
# 2025-12-12 18:12:35,206 INFO  [utils.assign_domains  ]        Created domain 'D_IN_WUI' with 4 values
# 2025-12-12 18:12:35,212 INFO  [utils.assign_domains  ]        Created domain 'D_ACTVDSCRP' with 61 values
# 2025-12-12 18:12:35,216 INFO  [utils.assign_domains  ]        Created domain 'D_ACTVCAT' with 8 values
# 2025-12-12 18:12:35,219 INFO  [utils.assign_domains  ]        Created domain 'D_USERDEFINED' with 2 values
# 2025-12-12 18:12:35,223 INFO  [utils.assign_domains  ]        Created domain 'D_BVT' with 8 values
# 2025-12-12 18:12:35,227 INFO  [utils.assign_domains  ]        Created domain 'D_RESIDUEFATE' with 15 values
# 2025-12-12 18:12:35,231 INFO  [utils.assign_domains  ]        Created domain 'D_UOM' with 6 values
# 2025-12-12 18:12:35,235 INFO  [utils.assign_domains  ]        Created domain 'D_TASKFORCE' with 5 values
# 2025-12-12 18:12:35,238 INFO  [utils.assign_domains  ]        Created domain 'D_PR_OWN_GR' with 7 values
# 2025-12-12 18:12:35,242 INFO  [utils.assign_domains  ]        Created domain 'D_FNDSRC' with 11 values
# 2025-12-12 18:12:35,246 INFO  [utils.assign_domains  ]        Created domain 'D_AGENCY' with 8 values
# 2025-12-12 18:12:35,251 INFO  [utils.assign_domains  ]        Created domain 'D_ORGANIZATION' with 31 values
# 2025-12-12 18:12:35,255 INFO  [utils.assign_domains  ]        Warning: 1 rows with NULL values were dropped from 'D_DATASTATUS'
# 2025-12-12 18:12:35,255 INFO  [utils.assign_domains  ]        Created domain 'D_DATASTATUS' with 2 values
# 2025-12-12 18:12:35,260 INFO  [utils.assign_domains  ]        Created domain 'D_DATAMSG' with 3 values
# 2025-12-12 18:12:35,263 INFO  [utils.assign_domains  ]        Created domain 'D_VERFIEDMSG' with 2 values
# 2025-12-12 18:12:35,267 INFO  [utils.assign_domains  ]        Created domain 'D_TRMT_GEOM' with 4 values
# 2025-12-12 18:12:35,268 INFO  [utils.assign_domains  ]        Assign domains to project-related columns
# 2025-12-12 18:12:35,278 INFO  [utils.assign_domains  ]        Assign domains to treatment-related columns
# 2025-12-12 18:12:35,291 INFO  [utils.assign_domains  ]        Assign domains to activity-related columns
# 2025-12-12 18:12:35,312 INFO  [enrich.Timber_NSpatial]     step 10/10 Save Result...
# Memory usage: 12244.54 MB
